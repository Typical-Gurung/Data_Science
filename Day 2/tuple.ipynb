# %%
thistuple=('apple','banana','cheery','apple','cheery',1,False)
print(thistuple)
# Out:
# ('apple', 'banana', 'cheery', 'apple', 'cheery', 1, False)

# %%
thistuple=('apple','banana','cheery')
print(thistuple[-1])
# Out:
# cheery

# %%
thistuple=('apple','banana','cheery','apple','cheery',1,False)
print(thistuple[2:5])
# Out:
# ('cheery', 'apple', 'cheery')

# %%
thistuple=('apple','banana','cheery')
if 'apple' in thistuple:
    print("yes, apple is in the fruit tuple")
# Out:
# yes, apple is in the fruit tuple

# %%
x=('apple','banana','cheery')
y=list(x)
y[1]='kiwi'
x=tuple(y)
print(x)
# Out:
# ('apple', 'kiwi', 'cheery')

# %%
thistuple=('apple','banana','cheery')
y=list(thistuple)
y.append("orange")
thistuple=tuple(y)
print(thistuple)
# Out:
# ('apple', 'banana', 'cheery', 'orange')

# %%
thistuple=('apple','banana','cheery')
y=('orange',)
thistuple += y
print(thistuple)
# Out:
# ('apple', 'banana', 'cheery', 'orange')

# %%
thistuple=('apple','banana','cheery')
y=list(thistuple)
y.remove('apple')
thistuple=tuple(y)
print(thistuple)
# Out:
# ('banana', 'cheery')

# %%
thistuple=('apple','banana','cheery')
del thistuple
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 4
#       2 thistuple=('apple','banana','cheery')
#       3 del thistuple
# ----> 4 print(thistuple)
#
# NameError: name 'thistuple' is not defined

# %%
fruits=('apple',"banana","cheery")
(green,yellow,red)=fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cheery

# %%
fruits=('apple',"banana",'cheery','strawberry','raspberry')
(green,yellow,*red)=fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cheery', 'strawberry', 'raspberry']

# %%
red
# Out:
# ['cheery', 'strawberry', 'raspberry']

# %%
thistuple=('apple','banana','cheery')
for i in range(len(thistuple)):
    print(thistuple[i])
# Out:
# apple
# banana
# cheery

# %%
thistuple=('apple','banana','cheery')
i=0
while i<len(thistuple):
    print(thistuple[i])
    i=i+1
# Out:
# apple
# banana
# cheery

# %%
tuple1=('a','b','c')
tuple2=(1,2,3)
tuple3=tuple1+tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
fruits=('apple','banana','cheery')
mytuple= fruits*3
print(mytuple)
# Out:
# ('apple', 'banana', 'cheery', 'apple', 'banana', 'cheery', 'apple', 'banana', 'cheery')

# %%
thiset={'apple','banana','cheery','apple'}
print(thiset)
# Out:
# {'cheery', 'apple', 'banana'}

# %%
thiset={'apple','banana','cheery',True,1,2}
print(thiset)
# Out:
# {True, 2, 'apple', 'banana', 'cheery'}

# %%
thiset={'apple','banana','cheery'}
for x in thiset:
    print(x)
# Out:
# cheery
# apple
# banana

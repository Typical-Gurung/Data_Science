# %%
thislist=["Apple","Banana","Cherry"]
print(thislist)
# Out:
# ['Apple', 'Banana', 'Cherry']

# %%
cd ..
# Out:
# d:\Data_Science

# %%
thislist=["mango","mango"]
print(thislist)
# Out:
# ['mango', 'mango']

# %%
a=[1,True,2,'Jason']
a
# Out:
# [1, True, 2, 'Jason']

# %%
thislist=["Apple","Banana","Hd","kiwi","melon","mango","orange"]
print(thislist[-4:-1])
# Out:
# ['kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cheery"]
thislist[1]="black"
print(thislist)
# Out:
# ['apple', 'black', 'cheery']

# %%
thislist=['apple','banana','cheery','orange','kiwi']
thislist[1:3]=['black','water']
print(thislist)
# Out:
# ['apple', 'black', 'water', 'orange', 'kiwi']

# %%
thislist.insert(2,'watermelon')
print(thislist)
# Out:
# ['apple', 'black', 'watermelon', 'water', 'orange', 'kiwi']

# %%
thislist=['apple','banana','cheery']
thislist.append('orange')
print(thislist)
# Out:
# ['apple', 'banana', 'cheery', 'orange']

# %%
thislist=['apple','banana','cheery']
thislist.insert(1,'orange')
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cheery']

# %%
thislist=['mango','banana','cheery']
tropical=['mango','pineapple','papaya']
thislist.extend(tropical)
print(thislist)
# Out:
# ['mango', 'banana', 'cheery', 'mango', 'pineapple', 'papaya']

# %%
thislist=['mango','banana','cheery']
thislist.remove(thislist[0])
print(thislist)
# Out:
# ['banana', 'cheery']

# %%
thislist=['apple','banana','cheery']
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %%
thislist=['apple','banana','cheery']
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cheery']

# %%
thislist=['apple','banana','cheery']
for x in thislist:
 print(x)
# Out:
# apple
# banana
# cheery

# %%
thislist=['apple','banana','cheery']
[print(x) for x in thislist]
# Out:
# apple
# banana
# cheery
# [None, None, None]

# %%
fruits=['apple','banana','cheery','kiwi','mango']
newlist=[]
for x in fruits:
    if 'a' in x:
        
        newlist.append(x)
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
thislist=['apple','mango','kiwi','pineapple','banana',]
thislist.sort()
print(thislist)
# Out:
# ['apple', 'banana', 'kiwi', 'mango', 'pineapple']

# %%
thislist=['apple','mango','kiwi','pineapple','banana',]
thislist.sort(reverse=True)
print(thislist)
# Out:
# ['pineapple', 'mango', 'kiwi', 'banana', 'apple']

# %%
def myfunc(n):
    return abs(n-50)
thislist=[100,50,65,82,23]
thislist.sort(key=myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]
